# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('2019.csv')

# %%
df.head()

# %%
print(df.shape)
print(df.columns.tolist())

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.dtypes
